# %% [markdown]
# Reference link to configure and use jbang in jupyter
#
# [Jupyter tutorial](https://github.com/jbangdev/jbang-jupyter-tutorial/blob/main/jbang_tutorial.ipynb)

# %%
# !jbang version
# Out:
# 0.141.0

# %%
# !jbang -c System.out.println("Hello World!")

# %%
# !jbang -c System.out.println(String.format("Hello %s", args[0])) Universe
# Out:
# ) was unexpected at this time.

# %%
# !jbang ../algorithm/disjoint_union_set/CheckIfItemRelated.java
# Out:
# --- Start execution ---
# Is 0 and 1 connected? true
# Is 0 and 2 connected? false
